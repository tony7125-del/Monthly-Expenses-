# %% [markdown]
#   ========**Receipt of Monthly Expensises======**

# %% [markdown]
# This below will be showing  my monthly expensises ranging from food ,electricity , water and other day-to-day expensinse .
# It will be broken down to smaller categories.

# %%
#Bank Account Current Amount
Current_Amount= '$3000'

#Monthly Expensises
food  = '$500'
electricity = '$100'
water = '$100'
rent = '$1000'
transport = '$250'
clothes ='$200'
data = '$50'
fuel = '$350'
insurance ='$150'
Total_epensises ='$2500'

#Balance Amount
Available_balance = '$300'

# %%
print('################################################')
print('--------------Monthly Expensise-----------------')
print(f'Current Amount  :{Current_Amount}')

print('------------------------------------------------')
print(f'Food            :{food}')
print(f'Electricity     :{electricity}')
print(f'Water           :{water}')
print(f'Rent            :{rent}')
print(f'Transport       :{transport}')
print(f'Clothes         :{clothes}')
print(f'Data            :{data}')
print(f'Fuel            :{fuel}')
print(f'Insurence       :{insurance}')
print('------------------------------------------------')
print(f'Total Expensise :{Total_epensises}') 

print('################################################') 

print(f'Available Balance:{Available_balance}')

print('**************************************************')
print(f'Date             :10/08/2025')
print(f'Time             :15:15')
print('##################################################')
# Out:
# ################################################
# --------------Monthly Expensise-----------------
# Current Amount  :$3000
# ------------------------------------------------
# Food            :$500
# Electricity     :$100
# Water           :$100
# Rent            :$1000
# Transport       :$250
# Clothes         :$200
# Data            :$50
# Fuel            :$350
# Insurence       :$150
# ------------------------------------------------
# Total Expensise :$2500
# ################################################
# Available Balance:$300
# **************************************************
# Date             : 10/08/2025
# Time             :15:15
# ##################################################
